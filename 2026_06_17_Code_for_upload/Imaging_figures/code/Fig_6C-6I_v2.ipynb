# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os as os
import re as re
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
import matplotlib

from matplotlib.lines import Line2D
import matplotlib
import matplotlib.colors as mcolors
from matplotlib.colors import PowerNorm

# %%
# Read in the clustering data which Michael sent me
files = pd.read_csv('../data/Radius_100_patient_id_edited.csv')
files.head()
# Out:
#    Unnamed: 0                              Entry ID  Cell ID Cell Type  \
# 0           0  7142785f-c543-4768-9a8c-3153238275a9        5     CD8_T
# 1           1  7142785f-c543-4768-9a8c-3153238275a9        8     CD8_T
# 2           2  7142785f-c543-4768-9a8c-3153238275a9       95     CD8_T
# 3           3  7142785f-c543-4768-9a8c-3153238275a9      148     CD8_T
# 4           4  7142785f-c543-4768-9a8c-3153238275a9      153     CD8_T
#
#          Neg     CD8_T     CD4_T  Endothelial   Stromal      HSPC    UMAP_1  \
# 0  14.514444  2.689997  0.000000     0.508647  0.473824  2.789986 -2.888258
# 1  14.988450  2.622916  0.000000     0.522399  0.407936  3.250461 -2.888675
# 2  15.129865  2.792207  0.000000     0.760356  0.000000  0.379367 -3.360949
# 3  17.181909  3.216538  0.000000     1.220715  0.000000  0.426072 -4.089715
# 4   4.583257  1.000000  0.710311     0.000000  3.059426  2.314174 -5.261656
#
#      UMAP_2  Leiden_Group  PID  tp  pid_tp
# 0 -2.316883            18  P08  C1  P08_C1
# 1 -2.320224            18  P08  C1  P08_C1
# 2 -2.057606            13  P08  C1  P08_C1
# 3 -1.429748            13  P08  C1  P08_C1
# 4  8.218327             8  P08  C1  P08_C1

# %%
# Read in data which specifies the color of each cell type
colors = pd.read_excel('../data/cell_type_colors.xlsx', sheet_name = '2026_02_23')
colors = colors.loc[colors['Cell_Type'] != 'Neg', :] # Remove the negative cells which I am not plotting
color_dict = dict(zip(colors['Cell_Type'], colors['Color']))
del color_dict['Mixed']

# %%
# Find the maximum for each cell typw (i.e how many cells map back to a specific hexagon)
global_vmax = {}
fig_temp, ax_temp = plt.subplots(ncols=5)
for num, i in enumerate(color_dict.keys()):
    cell = files.loc[files['Cell Type'] == i, :]
    n_cells = cell.shape[0]
    print(n_cells)
    hb = ax_temp[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'],
                              gridsize=30, mincnt=1,
                              C=np.ones(n_cells),
                              reduce_C_function=lambda x: len(x) / n_cells)
    global_vmax[i] = hb.get_array().max()
    
plt.close(fig_temp)
# Out:
# 510447
# 120389
# 53043
# 171585
# 190149

# %%
# Read in a csv file which details the outline of the UMAP plot
outline = pd.read_csv('../data/edited_umap_outline.csv')
outline
# Out:
#              x          y
# 0     1.775218 -12.395516
# 1     1.673625 -12.372126
# 2     1.532197 -12.324951
# 3     1.390768 -12.259685
# 4     1.318584 -12.216538
# ...        ...        ...
# 1037  4.785053 -12.243073
# 1038  4.643625 -12.291336
# 1039  4.502196 -12.332936
# 1040  4.360768 -12.368438
# 1041  1.775218 -12.395516
#
# [1042 rows x 2 columns]

# %%
cell
# Out:
#          Unnamed: 0                              Entry ID  Cell ID Cell Type  \
# 1852           1852  7142785f-c543-4768-9a8c-3153238275a9      169     CD4_T
# 1853           1853  7142785f-c543-4768-9a8c-3153238275a9      178     CD4_T
# 1854           1854  7142785f-c543-4768-9a8c-3153238275a9      198     CD4_T
# 1855           1855  7142785f-c543-4768-9a8c-3153238275a9      339     CD4_T
# 1856           1856  7142785f-c543-4768-9a8c-3153238275a9      357     CD4_T
# ...             ...                                   ...      ...       ...
# 1042944     1044273  33277076-7c0c-455a-90c9-f2dc9968c39d    37461     CD4_T
# 1042945     1044274  33277076-7c0c-455a-90c9-f2dc9968c39d    37463     CD4_T
# 1042946     1044275  33277076-7c0c-455a-90c9-f2dc9968c39d    37464     CD4_T
# 1042947     1044276  33277076-7c0c-455a-90c9-f2dc9968c39d    37465     CD4_T
# 1042948     1044277  33277076-7c0c-455a-90c9-f2dc9968c39d    37467     CD4_T
#
#                Neg     CD8_T      CD4_T  Endothelial   Stromal      HSPC  \
# 1852      5.984040  0.710311   1.000000     0.000000  2.700619  2.466208
# 1853     18.058508  0.844666   2.970997     3.291240  0.212389  0.588444
# 1854     17.627597  1.109990   3.027183     3.184900  0.115988  0.598981
# 1855     20.432528  1.694289   4.134866     1.829917  0.061471  0.460739
# 1856     20.853320  1.583683   3.773250     1.494310  0.052439  0.861373
# ...            ...       ...        ...          ...       ...       ...
# 1042944   1.759422  0.000000  16.736220     0.000000  0.000000  0.000000
# 1042945   9.373890  0.000000  10.917763     0.000000  0.000000  0.000000
# 1042946   0.921999  0.000000  18.686445     0.000000  0.000000  0.000000
# 1042947   1.518378  0.000000  20.684706     0.000000  0.000000  0.000000
# 1042948   2.294583  0.000000  22.105385     0.000000  0.000000  0.000000
#
#            UMAP_1     UMAP_2  Leiden_Group  PID  tp  pid_tp
# 1852    -4.713504   7.668851             8  P08  C1  P08_C1
# 1853    -3.491196   1.766809             5  P08  C1  P08_C1
# 1854    -3.592136   1.698209             5  P08  C1  P08_C1
# 1855    -2.752509  -0.043055            29  P08  C1  P08_C1
# 1856    -2.402153  -0.324486            29  P08  C1  P08_C1
# ...           ...        ...           ...  ...  ..     ...
# 1042944  1.925034 -11.508968            27  P21  C1  P21_C1
# 1042945  2.342592  -7.623320             0  P21  C1  P21_C1
# 1042946  3.176352 -12.164545            27  P21  C1  P21_C1
# 1042947  5.206979 -11.532766            27  P21  C1  P21_C1
# 1042948  6.354241 -10.492928            27  P21  C1  P21_C1
#
# [190149 rows x 16 columns]

# %%
from matplotlib.colors import PowerNorm

order = ['CD8_T', 'CD4_T', 'Endothelial', 'Stromal', 'HSPC']


fig, ax = plt.subplots(ncols=5, figsize=(7, 1.25))

for num, i in enumerate(order):
    
    # Create a colormap from white to your color
    base_color = color_dict[i]
    cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color]) #f8f8f8
    
    cell = files.loc[files['Cell Type'] == i, :]
    n_cells = cell.shape[0]
    hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'], 
                   gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                   C=np.ones(n_cells),
                   reduce_C_function=lambda x: len(x) / n_cells,
                   norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
    ax[num].plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
    cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0,  0.04])
    cb.outline.set_linewidth(0.0)
    cb.ax.tick_params(labelsize=7, length=1, pad=1)
    ax[num].set_ylim(-14, 25)
    ax[num].set_xlim(-15, 15)
    #ax[num].tick_params(labelsize=7, length=1, pad=0)
    ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    ax[num].spines[['top', 'right']].set_visible(False)
    ax[num].set_title(str(i), fontsize=8, y=0.95)
    ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)
plt.tight_layout()
#fig.savefig('../results/michael_clustering_v2/umap_hexbin_of_focal_cells_v2.pdf', dpi = 600)

# %%
from matplotlib.colors import PowerNorm

order = ['CD8_T', 'CD4_T', 'Endothelial', 'Stromal', 'HSPC']


fig, ax = plt.subplots(ncols=5, figsize=(7, 1.25))

for num, i in enumerate(order):
    
    # Create a colormap from white to your color
    base_color = color_dict[i]
    cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color]) #f8f8f8
    
    cell = files.loc[files['Cell Type'] == i, :]
    n_cells = cell.shape[0]
    hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'], 
                   gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                   C=np.ones(n_cells),
                   reduce_C_function=lambda x: len(x) / n_cells,
                   norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
    ax[num].plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
    cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0,  0.04])
    cb.outline.set_linewidth(0.0)
    cb.ax.tick_params(labelsize=7, length=1, pad=1)
    ax[num].set_ylim(-14, 25)
    ax[num].set_xlim(-15, 15)
    #ax[num].tick_params(labelsize=7, length=1, pad=0)
    ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    ax[num].spines[['top', 'right']].set_visible(False)
    ax[num].set_title(str(i), fontsize=8, y=0.95)
    ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)
plt.tight_layout()
#fig.savefig('../results/michael_clustering_v2/umap_hexbin_of_focal_cells_v2.pdf', dpi = 600)

# %%
# Add additional clinical information to the dataframe to allow for UMAP plots

outcomes = pd.read_excel('../data/Outcomes_master_simplified_updatedJan24_patient_updated.xlsx')
outcomes['Outcome_C6_revised_Vid'] = outcomes['Outcome_C6_revised_Vid'].replace('non-responder_2', 'Non-responder').replace('responder_1', 'Responder')
outcomes['Outcome_C12_CC486'] = outcomes['Outcome_C12_CC486'].replace('non-responder_2', 'Non-responder').replace('responder_1', 'Responder')

outcomes_6 = dict(zip(outcomes['PID'], outcomes['Outcome_C6_revised_Vid']))
outcomes_12 = dict(zip(outcomes['PID'], outcomes['Outcome_C12_CC486']))

files['outcomes_6'] = files['PID'].map(outcomes_6)
files['outcomes_12'] = files['PID'].map(outcomes_12)
files.head()
# Out:
#    Unnamed: 0                              Entry ID  Cell ID Cell Type  \
# 0           0  7142785f-c543-4768-9a8c-3153238275a9        5     CD8_T
# 1           1  7142785f-c543-4768-9a8c-3153238275a9        8     CD8_T
# 2           2  7142785f-c543-4768-9a8c-3153238275a9       95     CD8_T
# 3           3  7142785f-c543-4768-9a8c-3153238275a9      148     CD8_T
# 4           4  7142785f-c543-4768-9a8c-3153238275a9      153     CD8_T
#
#          Neg     CD8_T     CD4_T  Endothelial   Stromal      HSPC    UMAP_1  \
# 0  14.514444  2.689997  0.000000     0.508647  0.473824  2.789986 -2.888258
# 1  14.988450  2.622916  0.000000     0.522399  0.407936  3.250461 -2.888675
# 2  15.129865  2.792207  0.000000     0.760356  0.000000  0.379367 -3.360949
# 3  17.181909  3.216538  0.000000     1.220715  0.000000  0.426072 -4.089715
# 4   4.583257  1.000000  0.710311     0.000000  3.059426  2.314174 -5.261656
#
#      UMAP_2  Leiden_Group  PID  tp  pid_tp     outcomes_6    outcomes_12
# 0 -2.316883            18  P08  C1  P08_C1  Non-responder  Non-responder
# 1 -2.320224            18  P08  C1  P08_C1  Non-responder  Non-responder
# 2 -2.057606            13  P08  C1  P08_C1  Non-responder  Non-responder
# 3 -1.429748            13  P08  C1  P08_C1  Non-responder  Non-responder
# 4  8.218327             8  P08  C1  P08_C1  Non-responder  Non-responder

# %%
# Create a dictionary which specifies the patients and timepoints
patient_tp_dict = files.groupby('PID')['tp'].unique().to_dict()
patient_tp_dict

# Create a dictionary which specifies the patient outcomes
response_dict = {}
for x, y in patient_tp_dict.items():
    if 'C7' in y:
        response_dict[x] = outcomes_6[x]
    elif 'C12' in y:
        response_dict[x] = outcomes_12[x]
    elif 'Prog' in y:
        response_dict[x] =  'Non-responder'
    elif 'C1' in y:
        response_dict[x] = outcomes_6[x]
        
files['response'] = files['PID'].map(response_dict)

# %%
# Calculate the vmax for each plot so that the color scales are the same for 
response_outcomes = ['Responder', 'Non-responder']

global_vmax = {}
plot_times = ['C1']
fig_temp, ax_temp = plt.subplots(ncols=5)

for num, i in enumerate(response_outcomes):
    for suffix, mask in [('', files['tp'].isin(plot_times)), ('_not_c1', ~files['tp'].isin(plot_times))]:
        cell = files.loc[(files['response'] == i) & mask, :]
        n_cells = cell.shape[0]
        hb = ax_temp[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'],
                                  gridsize=30, mincnt=1,
                                  C=np.ones(n_cells),
                                  reduce_C_function=lambda x: len(x) / n_cells)
        global_vmax[i + suffix] = hb.get_array().max()

plt.close(fig_temp)

# %%
from matplotlib.gridspec import GridSpec

plot_times = ['C1']
response_outcomes = ['Responder', 'Non-responder']
color_dict = {'Responder': '#115284', 'Non-responder': '#fe9003'}
cmap_dict = {
    'Responder': mcolors.LinearSegmentedColormap.from_list('', ['white', color_dict['Responder']]),
    'Non-responder': mcolors.LinearSegmentedColormap.from_list('', ['white', color_dict['Non-responder']])
}
sample_counts = [
    len(files.loc[(files['response'] == 'Responder') & (files['tp'].isin(plot_times))]),
    len(files.loc[(files['response'] == 'Responder') & ~(files['tp'].isin(plot_times))]),
    len(files.loc[(files['response'] == 'Non-responder') & (files['tp'].isin(plot_times))]),
    len(files.loc[(files['response'] == 'Non-responder') & ~(files['tp'].isin(plot_times))])
]

fig = plt.figure(figsize=(3.5, 3.3872))
gs = GridSpec(2, 3, width_ratios=[1, 1, 0.08], figure=fig, hspace=0.4, wspace=0.3)

for row, y in enumerate(response_outcomes):
    ax_diag = fig.add_subplot(gs[row, 0])
    ax_resp = fig.add_subplot(gs[row, 1])
    ax_cb   = fig.add_subplot(gs[row, 2])

    # Diagnosis
    cell_diag = files.loc[(files['response'] == y) & (files['tp'].isin(plot_times))]
    n_diag = len(cell_diag)
    hb_diag = ax_diag.hexbin(
        x=cell_diag['UMAP_1'], y=cell_diag['UMAP_2'],
        gridsize=20, cmap=cmap_dict[y], mincnt=1,
        C=np.ones(n_diag),
        reduce_C_function=lambda x: len(x) / n_diag,
        norm=PowerNorm(gamma=0.5, vmin=0, vmax=global_vmax[y])
    )
    ax_diag.plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
    ax_diag.set_title(y + 's\nat diagnosis', fontsize=7)

    # Clinical response
    cell_resp = files.loc[(files['response'] == y) & ~(files['tp'].isin(plot_times))]
    n_resp = len(cell_resp)
    hb_resp = ax_resp.hexbin(
        x=cell_resp['UMAP_1'], y=cell_resp['UMAP_2'],
        gridsize=20, cmap=cmap_dict[y], mincnt=1,
        C=np.ones(n_resp),
        reduce_C_function=lambda x: len(x) / n_resp,
        norm=PowerNorm(gamma=0.5, vmin=0, vmax=global_vmax[y + '_not_c1'])
    )
    ax_resp.plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
    ax_resp.set_title(y + 's\nat clinical response', fontsize=7)

    # Colorbar in dedicated column
    # cb = fig.colorbar(hb_resp, cax=ax_cb, ticks=[0, 0.01])
    # cb.outline.set_linewidth(0.0)
    # cb.ax.tick_params(labelsize=7, length=1, pad=1)
    cb = fig.colorbar(hb_resp, cax=ax_cb, ticks=[0, 0.01])
    cb.set_ticks([0, 0.01])
    cb.set_ticklabels(['0', '0.01'])
    cb.mappable.set_clim(0, 0.01)  # forces bar to fill fully to top tick
    cb.outline.set_linewidth(0.0)
    cb.ax.tick_params(labelsize=7, length=1, pad=1)
    
    # Shrink the colorbar height
    pos = ax_cb.get_position()
    shrink = 0.5  # fraction of original height
    new_height = pos.height * shrink
    new_y = pos.y0 + (pos.height - new_height) / 2  # keep it centred
    ax_cb.set_position([pos.x0, new_y, pos.width, new_height])

    for axis in [ax_diag, ax_resp]:
        axis.spines[['top', 'right']].set_visible(False)
        axis.set_xticks([])
        axis.set_yticks([])
        axis.set_xlim(-17.5, 15)
        axis.set_ylim(-15, 27.5)

fig.savefig('../results/umap_hexbin_of_focal_cells_v2_with_mixed.pdf', dpi = 600)

# %%
# read_in_cluster_annotation
cluster_anno = pd.read_excel('../data/2026_03_10_all_clusters_annotated.xlsx')
cluster_anno = cluster_anno.loc[cluster_anno['Cell_Type'] == 'Mixed', :]

cluster_anno_dict = {'Mixed' : cluster_anno['Cluster'].to_list()}
cluster_anno_dict

mixed_clusters = cluster_anno['Cluster'].to_list()

# %%
color_dict
# Out:
# {'Responder': '#115284', 'Non-responder': '#fe9003'}

# %%
colors = pd.read_excel('../data/cell_type_colors.xlsx', sheet_name = '2026_02_23')
colors = colors.loc[colors['Cell_Type'] != 'Neg', :] # Remove the negative cells which I am not plotting
color_dict = dict(zip(colors['Cell_Type'], colors['Color']))

# %%
from matplotlib.colors import PowerNorm

order = ['CD8_T', 'CD4_T', 'Endothelial', 'Stromal', 'HSPC', 'Mixed']


fig, ax = plt.subplots(ncols=6, figsize=(8.2, 1.25))

for num, i in enumerate(order):
    if num <= 4:
        # Create a colormap from white to your color
        base_color = color_dict[i]
        cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color]) #f8f8f8
        
        cell = files.loc[files['Cell Type'] == i, :]
        n_cells = cell.shape[0]
        hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'], 
                       gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                       C=np.ones(n_cells),
                       reduce_C_function=lambda x: len(x) / n_cells,
                       norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
        ax[num].plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
        cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0,  0.04])
        cb.outline.set_linewidth(0.0)
        cb.ax.tick_params(labelsize=7, length=1, pad=1)
        ax[num].set_ylim(-14, 25)
        ax[num].set_xlim(-15, 15)
        #ax[num].tick_params(labelsize=7, length=1, pad=0)
        ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
        ax[num].spines[['top', 'right']].set_visible(False)
        ax[num].set_title(str(i), fontsize=8, y=0.95)
        ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)
    elif num >=5:
        cell = files.loc[files['Leiden_Group'].isin(mixed_clusters), :]
        n_cells = cell.shape[0]
        base_color = color_dict[i]
        cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color])
        hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'], 
                       gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                       C=np.ones(n_cells),
                       reduce_C_function=lambda x: len(x) / n_cells,
                       norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
        ax[num].set_ylim(-14, 25)
        ax[num].set_xlim(-15, 15)
        ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
        ax[num].spines[['top', 'right']].set_visible(False)
        ax[num].set_title(str(i), fontsize=8, y=0.95)
        ax[num].plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
        cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0,  0.04])
        ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)
        cb.outline.set_linewidth(0.0)
        cb.ax.tick_params(labelsize=7, length=1, pad=1)
        
plt.tight_layout()
fig.savefig('../results/umap_hexbin_of_focal_cells_v2_with_mixed.pdf', dpi = 600)

# %%
from matplotlib.colors import PowerNorm

order = ['CD8_T', 'CD4_T', 'Stromal', 'HSPC', 'Endothelial', 'Mixed']


fig, ax = plt.subplots(ncols=6, figsize=(8.2, 1.25))

for num, i in enumerate(order):
    if num <= 4:
        # Create a colormap from white to your color
        base_color = color_dict[i]
        cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color]) #f8f8f8
        
        cell = files.loc[files['Cell Type'] == i, :]
        n_cells = cell.shape[0]
        hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'], 
                       gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                       C=np.ones(n_cells),
                       reduce_C_function=lambda x: len(x) / n_cells,
                       norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
        ax[num].plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
        cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0, 0.04])
        cb.set_ticks([0, 0.04])
        cb.set_ticklabels(['0', '0.04'])
        cb.mappable.set_clim(0, 0.04)  # fills the bar fully to match labels
        cb.outline.set_linewidth(0.0)
        cb.ax.tick_params(labelsize=7, length=1, pad=1)
        cb.outline.set_linewidth(0.0)
        cb.ax.tick_params(labelsize=7, length=1, pad=1)
        ax[num].set_ylim(-14, 25)
        ax[num].set_xlim(-15, 15)
        #ax[num].tick_params(labelsize=7, length=1, pad=0)
        ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
        ax[num].spines[['top', 'right']].set_visible(False)
        ax[num].set_title(str(i), fontsize=8, y=0.95)
        ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)
    elif num >=5:
        cell = files.loc[files['Leiden_Group'].isin(mixed_clusters), :]
        n_cells = cell.shape[0]
        base_color = color_dict[i]
        cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color])
        hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'], 
                       gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                       C=np.ones(n_cells),
                       reduce_C_function=lambda x: len(x) / n_cells,
                       norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
        ax[num].set_ylim(-14, 25)
        ax[num].set_xlim(-15, 15)
        ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
        ax[num].spines[['top', 'right']].set_visible(False)
        ax[num].set_title(str(i), fontsize=8, y=0.95)
        ax[num].plot(outline['x'], outline['y'], linestyle = '--', color = 'black', linewidth=0.5)
        
        ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)
        cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0, 0.04])
        cb.set_ticks([0, 0.04])
        cb.set_ticklabels(['0', '0.04'])
        cb.mappable.set_clim(0, 0.04)  # fills the bar fully to match labels
        cb.outline.set_linewidth(0.0)
        cb.ax.tick_params(labelsize=7, length=1, pad=1)
        cb.outline.set_linewidth(0.0)
        cb.ax.tick_params(labelsize=7, length=1, pad=1)
        
plt.tight_layout()
fig.savefig('../results/umap_hexbin_of_focal_cells_v2_with_mixed.pdf', dpi = 600)

# %%
# from matplotlib.colors import PowerNorm

# order = ['CD8_T', 'CD4_T', 'Stromal', 'HSPC', 'Endothelial+Mixed']
# fig, ax = plt.subplots(ncols=5, figsize=(7.0, 1.25))

# for num, i in enumerate(order):
#     ax[num].plot(outline['x'], outline['y'], linestyle='--', color='black', linewidth=0.5)
#     ax[num].set_ylim(-14, 25)
#     ax[num].set_xlim(-15, 15)
#     ax[num].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
#     ax[num].spines[['top', 'right']].set_visible(False)
#     ax[num].set_title(str(i), fontsize=8, y=0.95)

#     if i != 'Endothelial+Mixed':
#         base_color = color_dict[i]
#         cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color])
#         cell = files.loc[files['Cell Type'] == i, :]
#         n_cells = cell.shape[0]
#         hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'],
#                        gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
#                        C=np.ones(n_cells),
#                        reduce_C_function=lambda x: len(x) / n_cells,
#                        norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())))
#         cb = plt.colorbar(hb, ax=ax[num], shrink=0.5, ticks=[0, 0.04])
#         cb.outline.set_linewidth(0.0)
#         cb.ax.tick_params(labelsize=7, length=1, pad=1)
#         ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)

#     else:
#         # --- Layer 1: Mixed (on bottom) ---
#         cell_mixed = files.loc[files['Leiden_Group'].isin(mixed_clusters), :]
#         n_mixed = cell_mixed.shape[0]
#         cmap_mixed = LinearSegmentedColormap.from_list('custom', ['none', color_dict['Mixed']])
#         hb_mixed = ax[num].hexbin(x=cell_mixed['UMAP_1'], y=cell_mixed['UMAP_2'],
#                        gridsize=30, cmap=cmap_mixed, mincnt=1, linewidths=0,
#                        C=np.ones(n_mixed),
#                        reduce_C_function=lambda x: len(x) / n_mixed,
#                        norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())),
#                        alpha=0.85)

#         # Dual colorbars
#         cb_endo = plt.colorbar(hb_endo, ax=ax[num], shrink=0.5, ticks=[0, 0.04], location='left')
#         cb_endo.outline.set_linewidth(0.0)
#         cb_endo.ax.tick_params(labelsize=7, length=1, pad=1)

#         cb_mixed = plt.colorbar(hb_mixed, ax=ax[num], shrink=0.5, ticks=[0, 0.04])
#         cb_mixed.outline.set_linewidth(0.0)
#         cb_mixed.ax.tick_params(labelsize=7, length=1, pad=1)
        
#         # --- Layer 2: Endothelial (on bottom) ---
#         cell_endo = files.loc[files['Cell Type'] == 'Endothelial', :]
#         n_endo = cell_endo.shape[0]
#         cmap_endo = LinearSegmentedColormap.from_list('custom', ['white', color_dict['Endothelial']])
#         hb_endo = ax[num].hexbin(x=cell_endo['UMAP_1'], y=cell_endo['UMAP_2'],
#                        gridsize=30, cmap=cmap_endo, mincnt=1, linewidths=0,
#                        C=np.ones(n_endo),
#                        reduce_C_function=lambda x: len(x) / n_endo,
#                        norm=PowerNorm(gamma=0.5, vmin=0, vmax=max(global_vmax.values())),
#                        alpha=0.85)

#         #

#         ax[num].text(s=f"#= {n_endo} / {n_mixed}", x=-14, y=22.5, fontsize=7)

# plt.tight_layout()
# fig.savefig('../results/umap_hexbin_of_focal_cells_v2_with_mixed.pdf', dpi=600)

# %%
from matplotlib.colors import PowerNorm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

order = ['CD8_T', 'CD4_T', 'Stromal', 'HSPC', 'Endothelial+Mixed']
fig, ax = plt.subplots(ncols=5, figsize=(7.0, 1.5), constrained_layout=True)
vmax = max(global_vmax.values())

def add_colorbar_inset(fig, hb, axis, loc='right'):
    if loc == 'right':
        cax = inset_axes(axis, width='7%', height='30%',
                         loc='lower right', borderpad=0.5,
                         bbox_to_anchor=(0.02, 0.02, 1, 1),
                         bbox_transform=axis.transAxes)
        cax.yaxis.set_ticks_position('right')
    else:
        cax = inset_axes(axis, width='7%', height='30%',
                         loc='lower left', borderpad=0.5,
                         bbox_to_anchor=(-0.02, 0.02, 1, 1),
                         bbox_transform=axis.transAxes)
        cax.yaxis.set_ticks_position('left')

    cb = fig.colorbar(hb, cax=cax)
    cax.set_clip_on(False)
    cb.mappable.set_clim(0, 0.04)  # <-- force colorbar to span 0→0.04 only
    cb.set_ticks([0, 0.04])
    cb.set_ticklabels(['0', '0.04'])
    cb.outline.set_linewidth(0.0)
    cb.ax.tick_params(labelsize=7, length=1, pad=1)
    return cb

def style_ax(axis):
    axis.plot(outline['x'], outline['y'], linestyle='--', color='black', linewidth=0.5)
    axis.set_ylim(-14, 25)
    axis.set_xlim(-15, 15)
    axis.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    axis.spines[['top', 'right']].set_visible(False)

for num, i in enumerate(order):
    style_ax(ax[num])
    ax[num].set_title(str(i), fontsize=8, y=0.95)

    if i != 'Endothelial+Mixed':
        base_color = color_dict[i]
        cmap = LinearSegmentedColormap.from_list('custom', ['white', base_color])
        cell = files.loc[files['Cell Type'] == i, :]
        n_cells = cell.shape[0]
        hb = ax[num].hexbin(x=cell['UMAP_1'], y=cell['UMAP_2'],
                            gridsize=30, cmap=cmap, mincnt=1, linewidths=0,
                            C=np.ones(n_cells),
                            reduce_C_function=lambda x: len(x) / n_cells,
                            norm=PowerNorm(gamma=0.5, vmin=0, vmax=vmax))
        add_colorbar_inset(fig, hb, ax[num], loc='right')
        ax[num].text(s=f"#= {n_cells}", x=-10, y=22.5, fontsize=8)

    else:
        cell_endo = files.loc[files['Cell Type'] == 'Endothelial', :]
        n_endo = cell_endo.shape[0]
        cmap_endo = LinearSegmentedColormap.from_list('custom', ['white', color_dict['Endothelial']])
        hb_endo = ax[num].hexbin(x=cell_endo['UMAP_1'], y=cell_endo['UMAP_2'],
                                 gridsize=30, cmap=cmap_endo, mincnt=1, linewidths=0,
                                 C=np.ones(n_endo),
                                 reduce_C_function=lambda x: len(x) / n_endo,
                                 norm=PowerNorm(gamma=0.5, vmin=0, vmax=vmax),
                                 alpha=0.85)
        cell_mixed = files.loc[files['Leiden_Group'].isin(mixed_clusters), :]
        n_mixed = cell_mixed.shape[0]
        cmap_mixed = LinearSegmentedColormap.from_list('custom', ['#ffffff00', color_dict['Mixed']])
        hb_mixed = ax[num].hexbin(x=cell_mixed['UMAP_1'], y=cell_mixed['UMAP_2'],
                                  gridsize=30, cmap=cmap_mixed, mincnt=1, linewidths=0,
                                  C=np.ones(n_mixed),
                                  reduce_C_function=lambda x: len(x) / n_mixed,
                                  norm=PowerNorm(gamma=0.5, vmin=0, vmax=vmax),
                                  alpha=0.85)
        add_colorbar_inset(fig, hb_endo, ax[num], loc='left')
        add_colorbar_inset(fig, hb_mixed, ax[num], loc='right')
        ax[num].text(s=f"#= {n_endo} / {n_mixed}", x=-14, y=22.5, fontsize=7)

#plt.tight_layout()
fig.savefig('../results/umap_hexbin_of_focal_cells_v2_with_mixed.pdf', dpi=600)
