# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import re
from matplotlib.lines import Line2D
import matplotlib.ticker as ticker
import random
import csv
from matplotlib.colors import to_rgb

# %%
# Read in data
cd8_t = pd.read_csv('../data/cd8_t_cells_cd8_low_removed_umap.csv', index_col = 0)
cd8_t.head()
# Out:
#    209Bi_CD45   Center  164Dy  166Er_CD34  Event_length  157Gd  113In_CD45  \
# 1    0.463586  508.199    0.0     1.45153            13    0.0         0.0
# 2    2.486070    0.000    0.0     0.00000            18    0.0         0.0
# 3    0.000000    0.000    0.0     7.91201            16    0.0         0.0
# 4    5.091210  582.354    0.0     0.00000            14    0.0         0.0
# 5    0.896022  419.084    0.0     0.00000            13    0.0         0.0
#
#    191Ir_DNA1  193Ir_DNA2  104Pd_CD45  ...  \
# 1    125.4630     252.016    0.000000  ...
# 2    121.0320     252.836    0.000000  ...
# 3     82.7162     192.006    0.000000  ...
# 4    199.5410     317.372    0.000000  ...
# 5    164.2140     389.681    0.692141  ...
#
#    171Yb_Granzyme_B_asinh_coarseAlign_fineAlign  \
# 1                                      0.126867
# 2                                      0.975536
# 3                                      5.615166
# 4                                      6.025747
# 5                                      3.764776
#
#    172Yb_CD38_asinh_coarseAlign_fineAlign  \
# 1                                2.189834
# 2                                1.903271
# 3                                1.859332
# 4                                1.367487
# 5                                1.084292
#
#    173Yb_CD14_asinh_coarseAlign_fineAlign  \
# 1                                0.122775
# 2                                0.006609
# 3                                0.014530
# 4                                0.014530
# 5                                0.014530
#
#    174Yb_HLA-DR_asinh_coarseAlign_fineAlign  \
# 1                                  0.347940
# 2                                  0.504978
# 3                                  0.073580
# 4                                  0.073580
# 5                                  0.073580
#
#    176Yb_CD56_asinh_coarseAlign_fineAlign  Alignment_MC_fineAlign  \
# 1                                0.044064                       5
# 2                                4.161595                       5
# 3                                0.054384                       7
# 4                                3.197923                       7
# 5                                2.563063                       7
#
#    FlowSOM_cluster  FlowSOM_metacluster    UMAP_X    UMAP_Y
# 1              144                   35 -1.817426  7.321785
# 2               57                   18  4.705129  3.655561
# 3               70                   22 -2.416794 -2.556074
# 4               49                   15  1.031044 -5.505780
# 5               44                   12  2.328280 -1.976762
#
# [5 rows x 68 columns]

# %%
# Read in patient alias
patient_alias = pd.read_excel('../data/patient_alias_from_2025.xlsx', nrows= 40)
patient_alias_dict = dict(zip(patient_alias['PID'].astype(str), patient_alias['alias']))
patient_alias_dict

control_alias = pd.read_csv('../data/healthy_control.csv')
control_alias['key'] = control_alias['key'].str.replace('Healthy_BMA_67y_Male', 'Healthy_BMA_67Y_Male')

control_alias_dict = dict(zip(control_alias['key'].str.replace('_T_Cell_Panel.fcs', ''), control_alias['value'].str.replace('.fcs', '')))

# %%
# Rename the filenames
filename_dict = {}
for i in cd8_t['FileName'].unique():
    if i.startswith('6'):
        x = i.split('_')[0] + '_' + i.split('_')[1]
        x = x.replace('_', '')
        z = '_'.join(i.split('_')[2:])
        filename_dict[i] = patient_alias_dict[x] + '_' + z
    elif i.startswith('Healthy'):
        #x = i.split('_')[0] + '_' + i.split('_')[1] + '_' + i.split('_')[2]
        x = i.replace('_T_Cell_Panel', '')
        filename_dict[i] = control_alias_dict[x] + '_T_Cell_Panel'

cd8_t['FileName'] = cd8_t['FileName'].map(filename_dict)

# %%
# Rename the filenames
patient_id_dict = {}
for i in cd8_t['Patient_ID'].unique():
    if i.startswith('6'):
        patient_id_dict[i] = patient_alias_dict[i.replace('_', '').replace('612500042', '61250004')]
    elif i.startswith('Healthy'):
        #x = i.split('_')[0] + '_' + i.split('_')[1] + '_' + i.split('_')[2]
        x = i.replace('_T_Cell_Panel', '')
        patient_id_dict[i] = control_alias_dict[x]

cd8_t['Patient_ID'] = cd8_t['Patient_ID'].map(patient_id_dict)

# %%
cd8_t
# Out:
# array(['P08_C1_D8_T_Cell_Panel', 'P08_C7_D1_T_Cell_Panel',
#        'P08_C7_D22_T_Cell_Panel', 'P08_SPD_T_Cell_Panel',
#        'P24_C1_D1_T_Cell_Panel', 'P24_C1_D8_T_Cell_Panel',
#        'P24_C7_D1_T_Cell_Panel', 'P19_C1_D1_T_Cell_Panel',
#        'P19_C1_D8_T_Cell_Panel', 'P19_C7_D1_T_Cell_Panel',
#        'P19_C7_D22_T_Cell_Panel', 'P12_C1_D1_T_Cell_Panel',
#        'P12_C1_D8_T_Cell_Panel', 'P12_C12_D29_T_Cell_Panel',
#        'P12_C7_D22_T_Cell_Panel', 'P04_C1_D1_T_Cell_Panel',
#        'P04_C1_D8_T_Cell_Panel', 'P04_C12_D29_T_Cell_Panel',
#        'P04_C7_D22_T_Cell_Panel', 'P03_C1_D1_T_Cell_Panel',
#        'P03_C1_D8_T_Cell_Panel', 'P03_C12_D29_T_Cell_Panel',
#        'P03_C7_D1_T_Cell_Panel', 'P03_C7_D22_T_Cell_Panel',
#        'P27_C1_D1_T_Cell_Panel', 'P38_C1_D1_T_Cell_Panel',
#        'P38_C1_D8_T_Cell_Panel', 'P06_C12_D29_T_Cell_Panel',
#        'P06_C7_D1_T_Cell_Panel', 'P06_C7_D22_T_Cell_Panel',
#        'P10_C1_D1_T_Cell_Panel', 'P10_C1_D8_T_Cell_Panel',
#        'P10_C12_D29_T_Cell_Panel', 'P10_C7_D1_T_Cell_Panel',
#        'P10_C7_D22_T_Cell_Panel', 'P16_C1_D1_T_Cell_Panel',
#        'P16_C1_D8_T_Cell_Panel', 'P16_C7_D1_T_Cell_Panel',
#        'P16_C7_D22_T_Cell_Panel', 'P14_C1_D1_T_Cell_Panel',
#        'P14_C1_D8_T_Cell_Panel', 'P14_C7_D22_T_Cell_Panel',
#        'P14_SPD_T_Cell_Panel', 'P05_C1_D1_T_Cell_Panel',
#        'P05_C1_D8_T_Cell_Panel', 'P05_C12_D29_T_Cell_Panel',
#        'P02_C1_D1_T_Cell_Panel', 'P02_C1_D8_T_Cell_Panel',
#        'P02_C7_D1_T_Cell_Panel', 'P02_C7_D22_T_Cell_Panel',
#        'P02_SPD_2_T_Cell_Panel', 'P02_SPD_T_Cell_Panel',
#        'P01_C1_D1_T_Cell_Panel', 'P01_C1_D8_T_Cell_Panel',
#        'P01_C12_D29_T_Cell_Panel', 'P01_C7_D1_T_Cell_Panel',
#        'P01_C7_D22_T_Cell_Panel', 'P11_C1_D1_T_Cell_Panel',
#        'P11_C1_D8_T_Cell_Panel', 'P11_C12_D29_T_Cell_Panel',
#        'P11_C7_D1_T_Cell_Panel', 'P11_C7_D22_T_Cell_Panel',
#        'P28_C1_D1_T_Cell_Panel', 'P28_C1_D8_T_Cell_Panel',
#        'P07_C1_D1_T_Cell_Panel', 'P07_C1_D8_T_Cell_Panel',
#        'P07_C12_D29_T_Cell_Panel', 'P07_C7_D1_T_Cell_Panel',
#        'P07_C7_D22_T_Cell_Panel', 'P15_C1_D8_T_Cell_Panel',
#        'P20_C1_D8_T_Cell_Panel', 'P20_C7_D22_T_Cell_Panel',
#        'P26_C1_D1_T_Cell_Panel', 'P26_C1_D8_T_Cell_Panel',
#        'P17_C1_D1_T_Cell_Panel', 'P17_C1_D8_T_Cell_Panel',
#        'P17_C7_D1_T_Cell_Panel', 'P17_C7_D22_T_Cell_Panel',
#        'P17_SPD_T_Cell_Panel', 'P18_C1_D1_T_Cell_Panel',
#        'P18_C1_D8_T_Cell_Panel', 'P18_C7_D1_T_Cell_Panel',
#        'P18_C7_D22_T_Cell_Panel', 'P18_SPD_T_Cell_Panel',
#        'P22_C1_D1_T_Cell_Panel', 'P22_C1_D8_T_Cell_Panel',
#        'P22_C7_D1_T_Cell_Panel', 'P22_C7_D22_T_Cell_Panel',
#        'P25_C1_D1_T_Cell_Panel', 'P25_C1_D8_T_Cell_Panel',
#        'P13_C1_D1_T_Cell_Panel', 'P13_C1_D8_T_Cell_Panel',
#        'P13_C12_D29_T_Cell_Panel', 'P13_C7_D1_T_Cell_Panel',
#        'P13_C7_D22_T_Cell_Panel', 'P21_C1_D1_T_Cell_Panel',
#        'P21_C1_D8_T_Cell_Panel', 'P21_C7_D1_T_Cell_Panel',
#        'P21_C7_D22_T_Cell_Panel', 'Control_14_T_Cell_Panel',
#        'Control_1_T_Cell_Panel', 'Control_17_T_Cell_Panel',
#        'Control_19_T_Cell_Panel', 'Control_13_T_Cell_Panel',
#        'Control_18_T_Cell_Panel', 'Control_9_T_Cell_Panel',
#        'Control_7_T_Cell_Panel', 'Control_15_T_Cell_Panel',
#        'Control_3_T_Cell_Panel', 'Control_2_T_Cell_Panel',
#        'Control_6_T_Cell_Panel', 'Control_8_T_Cell_Panel',
#        'Control_5_T_Cell_Panel', 'Control_16_T_Cell_Panel',
#        'Control_10_T_Cell_Panel', 'Control_4_T_Cell_Panel',
#        'Control_12_T_Cell_Panel', 'Control_11_T_Cell_Panel'], dtype=object)

# %%
cd8_t.to_csv('../data/cd8_t_cells_cd8_low_removed_umap_patient_updated.csv')
